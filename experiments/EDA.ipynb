# %%
# Import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('insurance.csv')
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
# Explore the features of the data

# %%
sns.histplot(x=df['age'], bins=20);

# %% [markdown]
# Observation: There are huge number of people around the age of _20_

# %%
sns.histplot(x=df['sex'], bins=20);

# %% [markdown]
# Observation: Both gender have almost the same number of people.

# %%
sns.histplot(x=df['bmi'], bins=25, kde=True);

# %% [markdown]
# Observation: BMI follows almost normal distribution.

# %%
sns.histplot(x=df['children'], bins=15);

# %% [markdown]
# Observation: There are more number of people that does'nt have the children.

# %%
sns.histplot(x=df['smoker'], bins=15);

# %% [markdown]
# Observation: There are huge number of people that doesn't smoke.

# %%
sns.histplot(x=df['region'], bins=15);

# %%
df['sex'].value_counts()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64
